# %%
import requests

application = {'Destination Port': 53.0,
 'Flow Duration': 286300.0,
 'Total Fwd Packets': 1.0,
 'Total Backward Packets': 1.0,
 'Total Length of Fwd Packets': 45.0,
 'Total Length of Bwd Packets': 253.0,
 'Fwd Packet Length Max': 45.0,
 'Fwd Packet Length Min': 45.0,
 'Fwd Packet Length Mean': 45.0,
 'Fwd Packet Length Std': 0.0,
 'Bwd Packet Length Max': 253.0,
 'Bwd Packet Length Min': 253.0,
 'Bwd Packet Length Mean': 253.0,
 'Bwd Packet Length Std': 0.0,
 'Flow Bytes/s': 1040.866224,
 'Flow Packets/s': 6.985679357,
 'Flow IAT Mean': 286300.0,
 'Flow IAT Std': 0.0,
 'Flow IAT Max': 286300.0,
 'Flow IAT Min': 286300.0,
 'Fwd IAT Total': 0.0,
 'Fwd IAT Mean': 0.0,
 'Fwd IAT Std': 0.0,
 'Fwd IAT Max': 0.0,
 'Fwd IAT Min': 0.0,
 'Bwd IAT Total': 0.0,
 'Bwd IAT Mean': 0.0,
 'Bwd IAT Std': 0.0,
 'Bwd IAT Max': 0.0,
 'Bwd IAT Min': 0.0,
 'Fwd PSH Flags': 0.0,
 'Fwd URG Flags': 0.0,
 'Fwd Header Length': 20.0,
 'Bwd Header Length': 20.0,
 'Fwd Packets/s': 3.4928396,
 'Bwd Packets/s': 3.4928396,
 'Min Packet Length': 45.0,
 'Max Packet Length': 253.0,
 'Packet Length Mean': 114.3,
 'Packet Length Std': 120.06,
 'Packet Length Variance': 14421.333,
 'FIN Flag Count': 0.0,
 'SYN Flag Count': 0.0,
 'RST Flag Count': 0.0,
 'PSH Flag Count': 0.0,
 'ACK Flag Count': 0.0,
 'URG Flag Count': 0.0,
 'CWE Flag Count': 0.0,
 'ECE Flag Count': 0.0,
 'Down/Up Ratio': 1.0,
 'Average Packet Size': 171.5,
 'Avg Fwd Segment Size': 45.0,
 'Avg Bwd Segment Size': 253.0,
 'Fwd Header Length.1': 20.0,
 'Subflow Fwd Packets': 1.0,
 'Subflow Fwd Bytes': 45.0,
 'Subflow Bwd Packets': 1.0,
 'Subflow Bwd Bytes': 253.0,
 'Init_Win_bytes_forward': -1.0,
 'Init_Win_bytes_backward': -1.0,
 'act_data_pkt_fwd': 0.0,
 'min_seg_size_forward': 20.0,
 'Active Mean': 0.0,
 'Active Std': 0.0,
 'Active Max': 0.0,
 'Active Min': 0.0,
 'Idle Mean': 0.0,
 'Idle Std': 0.0,
 'Idle Max': 0.0,
 'Idle Min': 0.0}

url = 'http://192.168.1.6:8888/predict'
resp = requests.post(url, json=application)

print('Ответ сервера:', resp) #200 - всё гуд
print()
print('Предсказание:', resp.json())
# Out:
# Ответ сервера: <Response [200]>
#
# Предсказание: {'Prediction': 'BENIGN'}
